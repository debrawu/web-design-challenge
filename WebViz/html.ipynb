# %% [markdown]
# ## import csv to notebook

# %%
#IMPORT THINGS
import pandas as pd
import os

# %%
f_path = os.path.join('Resources', 'WeatherPy.csv')

read_csv = pd.read_csv(f_path)

read_csv.head()

weather_df = pd.DataFrame(read_csv)

# %%
print(weather_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>touros</td>
#       <td>-5.20</td>
#       <td>-35.46</td>
#       <td>75.20</td>
#       <td>83.0</td>
#       <td>20.0</td>
#       <td>4.70</td>
#       <td>BR</td>
#       <td>1.600300e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>kaeo</td>
#       <td>-35.10</td>
#       <td>173.78</td>
#       <td>63.88</td>
#       <td>60.0</td>
#       <td>6.0</td>
#       <td>8.48</td>
#       <td>NZ</td>
#       <td>1.600300e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>hobart</td>
#       <td>-42.88</td>
#       <td>147.33</td>
#       <td>50.00</td>
# ...
